# %%
import sys
sys.path.append("..")

from torch.utils.data import DataLoader

from gans.datasets import PokemonDataset
from gans.utils import show_batch

# %%
batch_size = 64
dataset = PokemonDataset(set="basic")
dl = DataLoader(dataset, batch_size, shuffle=True)

show_batch(dl)
